# %%
# !pip install easyocr
# !pip install opencv-python
# !pip install imutils
# !pip install matplotlib
# Out:
# Requirement already satisfied: easyocr in c:\users\vanshika\anaconda24\lib\site-packages (1.7.1)
# Requirement already satisfied: torch in c:\users\vanshika\anaconda24\lib\site-packages (from easyocr) (2.3.1)
# Requirement already satisfied: torchvision>=0.5 in c:\users\vanshika\anaconda24\lib\site-packages (from easyocr) (0.15.2a0)
# Requirement already satisfied: opencv-python-headless in c:\users\vanshika\anaconda24\lib\site-packages (from easyocr) (4.10.0.84)
# Requirement already satisfied: scipy in c:\users\vanshika\anaconda24\lib\site-packages (from easyocr) (1.10.1)
# Requirement already satisfied: numpy in c:\users\vanshika\anaconda24\lib\site-packages (from easyocr) (1.26.4)
# Requirement already satisfied: Pillow in c:\users\vanshika\anaconda24\lib\site-packages (from easyocr) (9.4.0)
# Requirement already satisfied: scikit-image in c:\users\vanshika\anaconda24\lib\site-packages (from easyocr) (0.20.0)
# Requirement already satisfied: python-bidi in c:\users\vanshika\anaconda24\lib\site-packages (from easyocr) (0.6.0)
# Requirement already satisfied: PyYAML in c:\users\vanshika\anaconda24\lib\site-packages (from easyocr) (6.0)
# Requirement already satisfied: Shapely in c:\users\vanshika\anaconda24\lib\site-packages (from easyocr) (2.0.5)
# Requirement already satisfied: pyclipper in c:\users\vanshika\anaconda24\lib\site-packages (from easyocr) (1.3.0.post5)
# Requirement already satisfied: ninja in c:\users\vanshika\anaconda24\lib\site-packages (from easyocr) (1.11.1.1)
# Requirement already satisfied: requests in c:\users\vanshika\anaconda24\lib\site-packages (from torchvision>=0.5->easyocr) (2.31.0)
# Requirement already satisfied: networkx>=2.8 in c:\users\vanshika\anaconda24\lib\site-packages (from scikit-image->easyocr) (3.1)
# Requirement already satisfied: imageio>=2.4.1 in c:\users\vanshika\anaconda24\lib\site-packages (from scikit-image->easyocr) (2.26.0)
# Requirement already satisfied: tifffile>=2019.7.26 in c:\users\vanshika\anaconda24\lib\site-packages (from scikit-image->easyocr) (2021.7.2)
# Requirement already satisfied: PyWavelets>=1.1.1 in c:\users\vanshika\anaconda24\lib\site-packages (from scikit-image->easyocr) (1.4.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\vanshika\anaconda24\lib\site-packages (from scikit-image->easyocr) (23.0)
# Requirement already satisfied: lazy_loader>=0.1 in c:\users\vanshika\anaconda24\lib\site-packages (from scikit-image->easyocr) (0.2)
# Requirement already satisfied: filelock in c:\users\vanshika\anaconda24\lib\site-packages (from torch->easyocr) (3.9.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\vanshika\anaconda24\lib\site-packages (from torch->easyocr) (4.12.2)
# Requirement already satisfied: sympy in c:\users\vanshika\anaconda24\lib\site-packages (from torch->easyocr) (1.11.1)
# Requirement already satisfied: jinja2 in c:\users\vanshika\anaconda24\lib\site-packages (from torch->easyocr) (3.1.2)
# Requirement already satisfied: fsspec in c:\users\vanshika\anaconda24\lib\site-packages (from torch->easyocr) (2024.6.1)
# Requirement already satisfied: mkl<=2021.4.0,>=2021.1.1 in c:\users\vanshika\anaconda24\lib\site-packages (from torch->easyocr) (2021.4.0)
# Requirement already satisfied: intel-openmp==2021.* in c:\users\vanshika\anaconda24\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch->easyocr) (2021.4.0)
# Requirement already satisfied: tbb==2021.* in c:\users\vanshika\anaconda24\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch->easyocr) (2021.13.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\vanshika\anaconda24\lib\site-packages (from jinja2->torch->easyocr) (2.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\vanshika\anaconda24\lib\site-packages (from requests->torchvision>=0.5->easyocr) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\vanshika\anaconda24\lib\site-packages (from requests->torchvision>=0.5->easyocr) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\vanshika\anaconda24\lib\site-packages (from requests->torchvision>=0.5->easyocr) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\vanshika\anaconda24\lib\site-packages (from requests->torchvision>=0.5->easyocr) (2024.7.4)
# Requirement already satisfied: mpmath>=0.19 in c:\users\vanshika\anaconda24\lib\site-packages (from sympy->torch->easyocr) (1.3.0)
# Requirement already satisfied: opencv-python in c:\users\vanshika\anaconda24\lib\site-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\vanshika\anaconda24\lib\site-packages (from opencv-python) (1.26.4)
# Requirement already satisfied: imutils in c:\users\vanshika\anaconda24\lib\site-packages (0.5.4)
# Requirement already satisfied: matplotlib in c:\users\vanshika\anaconda24\lib\site-packages (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\vanshika\anaconda24\lib\site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\vanshika\anaconda24\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\vanshika\anaconda24\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\vanshika\anaconda24\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in c:\users\vanshika\anaconda24\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\vanshika\anaconda24\lib\site-packages (from matplotlib) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\vanshika\anaconda24\lib\site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\vanshika\anaconda24\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\vanshika\anaconda24\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\vanshika\anaconda24\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
# !pip install easyocr
import cv2 
from matplotlib import pyplot as plt
import numpy as np
import easyocr
import imutils
import random
# Out:
# Requirement already satisfied: easyocr in c:\users\vanshika\anaconda24\lib\site-packages (1.7.1)
# Requirement already satisfied: torch in c:\users\vanshika\anaconda24\lib\site-packages (from easyocr) (2.3.1)
# Requirement already satisfied: torchvision>=0.5 in c:\users\vanshika\anaconda24\lib\site-packages (from easyocr) (0.15.2a0)
# Requirement already satisfied: opencv-python-headless in c:\users\vanshika\anaconda24\lib\site-packages (from easyocr) (4.10.0.84)
# Requirement already satisfied: scipy in c:\users\vanshika\anaconda24\lib\site-packages (from easyocr) (1.10.1)
# Requirement already satisfied: numpy in c:\users\vanshika\anaconda24\lib\site-packages (from easyocr) (1.26.4)
# Requirement already satisfied: Pillow in c:\users\vanshika\anaconda24\lib\site-packages (from easyocr) (9.4.0)
# Requirement already satisfied: scikit-image in c:\users\vanshika\anaconda24\lib\site-packages (from easyocr) (0.20.0)
# Requirement already satisfied: python-bidi in c:\users\vanshika\anaconda24\lib\site-packages (from easyocr) (0.6.0)
# Requirement already satisfied: PyYAML in c:\users\vanshika\anaconda24\lib\site-packages (from easyocr) (6.0)
# Requirement already satisfied: Shapely in c:\users\vanshika\anaconda24\lib\site-packages (from easyocr) (2.0.5)
# Requirement already satisfied: pyclipper in c:\users\vanshika\anaconda24\lib\site-packages (from easyocr) (1.3.0.post5)
# Requirement already satisfied: ninja in c:\users\vanshika\anaconda24\lib\site-packages (from easyocr) (1.11.1.1)
# Requirement already satisfied: requests in c:\users\vanshika\anaconda24\lib\site-packages (from torchvision>=0.5->easyocr) (2.31.0)
# Requirement already satisfied: networkx>=2.8 in c:\users\vanshika\anaconda24\lib\site-packages (from scikit-image->easyocr) (3.1)
# Requirement already satisfied: imageio>=2.4.1 in c:\users\vanshika\anaconda24\lib\site-packages (from scikit-image->easyocr) (2.26.0)
# Requirement already satisfied: tifffile>=2019.7.26 in c:\users\vanshika\anaconda24\lib\site-packages (from scikit-image->easyocr) (2021.7.2)
# Requirement already satisfied: PyWavelets>=1.1.1 in c:\users\vanshika\anaconda24\lib\site-packages (from scikit-image->easyocr) (1.4.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\vanshika\anaconda24\lib\site-packages (from scikit-image->easyocr) (23.0)
# Requirement already satisfied: lazy_loader>=0.1 in c:\users\vanshika\anaconda24\lib\site-packages (from scikit-image->easyocr) (0.2)
# Requirement already satisfied: filelock in c:\users\vanshika\anaconda24\lib\site-packages (from torch->easyocr) (3.9.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\vanshika\anaconda24\lib\site-packages (from torch->easyocr) (4.12.2)
# Requirement already satisfied: sympy in c:\users\vanshika\anaconda24\lib\site-packages (from torch->easyocr) (1.11.1)
# Requirement already satisfied: jinja2 in c:\users\vanshika\anaconda24\lib\site-packages (from torch->easyocr) (3.1.2)
# Requirement already satisfied: fsspec in c:\users\vanshika\anaconda24\lib\site-packages (from torch->easyocr) (2024.6.1)
# Requirement already satisfied: mkl<=2021.4.0,>=2021.1.1 in c:\users\vanshika\anaconda24\lib\site-packages (from torch->easyocr) (2021.4.0)
# Requirement already satisfied: intel-openmp==2021.* in c:\users\vanshika\anaconda24\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch->easyocr) (2021.4.0)
# Requirement already satisfied: tbb==2021.* in c:\users\vanshika\anaconda24\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch->easyocr) (2021.13.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\vanshika\anaconda24\lib\site-packages (from jinja2->torch->easyocr) (2.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\vanshika\anaconda24\lib\site-packages (from requests->torchvision>=0.5->easyocr) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\vanshika\anaconda24\lib\site-packages (from requests->torchvision>=0.5->easyocr) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\vanshika\anaconda24\lib\site-packages (from requests->torchvision>=0.5->easyocr) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\vanshika\anaconda24\lib\site-packages (from requests->torchvision>=0.5->easyocr) (2024.7.4)
# Requirement already satisfied: mpmath>=0.19 in c:\users\vanshika\anaconda24\lib\site-packages (from sympy->torch->easyocr) (1.3.0)
# C:\Users\Vanshika\anaconda24\Lib\site-packages\torchvision\io\image.py:13: UserWarning: Failed to load image Python extension: '[WinError 127] The specified procedure could not be found'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(
# C:\Users\Vanshika\anaconda24\Lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated
#   "class": algorithms.Blowfish,

# %%
img = cv2.imread("photo2.jpg")
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.title('Original Image')
plt.show()

gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY) #image converion into gray
bfilter = cv2.bilateralFilter(gray, 11, 17, 17) #Noise reduction
plt.imshow(cv2.cvtColor(bfilter, cv2.COLOR_BGR2RGB)) #processed image
plt.title('Processed Image')
# Out:
# Text(0.5, 1.0, 'Processed Image')

# %%
edged = cv2.Canny(bfilter, 30, 200) #Edge detection
plt.imshow(cv2.cvtColor(edged, cv2.COLOR_BGR2RGB))

# %%
# !pip install imutils
import imutils
keypoints = cv2.findContours(edged.copy(), cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE) #Find contours 
contours = imutils.grab_contours(keypoints) #Grab contours 
contours = sorted(contours, key=cv2.contourArea, reverse=True)[:10] #Sort contours
# Out:
# Requirement already satisfied: imutils in c:\users\vanshika\anaconda24\lib\site-packages (0.5.4)

# %%
#Loop over our contours to find the best possible approximate contour of 10 contours
location = None
for contour in contours:
    approx = cv2.approxPolyDP(contour, 10, True)
    if len(approx) == 4:
        location = approx
        break
     
print("Location: ", location)
# Out:
# Location:  [[[335 123]]
#
#  [[341 160]]
#
#  [[529 160]]
#
#  [[522 122]]]

# %%
mask = np.zeros(gray.shape, np.uint8) #create blank image with same dimensions as the original image
new_image = cv2.drawContours(mask, [location], 0,255, -1) #Draw contours on the mask image
new_image = cv2.bitwise_and(img, img, mask=mask) #Take bitwise AND between the original image and mask image

plt.imshow(cv2.cvtColor(new_image, cv2.COLOR_BGR2RGB)) #show the final image

# %%
(x,y) = np.where(mask==255) #Find the co-ordinates of the four corners of the document
(x1, y1) = (np.min(x), np.min(y)) #Find the top left corner
(x2, y2) = (np.max(x), np.max(y)) #Find the bottom right corner
cropped_image = gray[x1:x2+1, y1:y2+1] #Crop the image using the co-ordinates

plt.imshow(cv2.cvtColor(cropped_image, cv2.COLOR_BGR2RGB)) #show the cropped image

# %%
# !pip install easyocr
import easyocr
reader = easyocr.Reader(['en']) # easyocr reader object with english as the language
result = reader.readtext(cropped_image) #text reading 
result
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# Requirement already satisfied: easyocr in c:\users\vanshika\anaconda24\lib\site-packages (1.7.1)
# Requirement already satisfied: torch in c:\users\vanshika\anaconda24\lib\site-packages (from easyocr) (2.3.1)
# Requirement already satisfied: torchvision>=0.5 in c:\users\vanshika\anaconda24\lib\site-packages (from easyocr) (0.15.2a0)
# Requirement already satisfied: opencv-python-headless in c:\users\vanshika\anaconda24\lib\site-packages (from easyocr) (4.10.0.84)
# Requirement already satisfied: scipy in c:\users\vanshika\anaconda24\lib\site-packages (from easyocr) (1.10.1)
# Requirement already satisfied: numpy in c:\users\vanshika\anaconda24\lib\site-packages (from easyocr) (1.26.4)
# Requirement already satisfied: Pillow in c:\users\vanshika\anaconda24\lib\site-packages (from easyocr) (9.4.0)
# Requirement already satisfied: scikit-image in c:\users\vanshika\anaconda24\lib\site-packages (from easyocr) (0.20.0)
# Requirement already satisfied: python-bidi in c:\users\vanshika\anaconda24\lib\site-packages (from easyocr) (0.6.0)
# Requirement already satisfied: PyYAML in c:\users\vanshika\anaconda24\lib\site-packages (from easyocr) (6.0)
# Requirement already satisfied: Shapely in c:\users\vanshika\anaconda24\lib\site-packages (from easyocr) (2.0.5)
# Requirement already satisfied: pyclipper in c:\users\vanshika\anaconda24\lib\site-packages (from easyocr) (1.3.0.post5)
# Requirement already satisfied: ninja in c:\users\vanshika\anaconda24\lib\site-packages (from easyocr) (1.11.1.1)
# Requirement already satisfied: requests in c:\users\vanshika\anaconda24\lib\site-packages (from torchvision>=0.5->easyocr) (2.31.0)
# Requirement already satisfied: networkx>=2.8 in c:\users\vanshika\anaconda24\lib\site-packages (from scikit-image->easyocr) (3.1)
# Requirement already satisfied: imageio>=2.4.1 in c:\users\vanshika\anaconda24\lib\site-packages (from scikit-image->easyocr) (2.26.0)
# Requirement already satisfied: tifffile>=2019.7.26 in c:\users\vanshika\anaconda24\lib\site-packages (from scikit-image->easyocr) (2021.7.2)
# Requirement already satisfied: PyWavelets>=1.1.1 in c:\users\vanshika\anaconda24\lib\site-packages (from scikit-image->easyocr) (1.4.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\vanshika\anaconda24\lib\site-packages (from scikit-image->easyocr) (23.0)
# Requirement already satisfied: lazy_loader>=0.1 in c:\users\vanshika\anaconda24\lib\site-packages (from scikit-image->easyocr) (0.2)
# Requirement already satisfied: filelock in c:\users\vanshika\anaconda24\lib\site-packages (from torch->easyocr) (3.9.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\vanshika\anaconda24\lib\site-packages (from torch->easyocr) (4.12.2)
# Requirement already satisfied: sympy in c:\users\vanshika\anaconda24\lib\site-packages (from torch->easyocr) (1.11.1)
# Requirement already satisfied: jinja2 in c:\users\vanshika\anaconda24\lib\site-packages (from torch->easyocr) (3.1.2)
# Requirement already satisfied: fsspec in c:\users\vanshika\anaconda24\lib\site-packages (from torch->easyocr) (2024.6.1)
# Requirement already satisfied: mkl<=2021.4.0,>=2021.1.1 in c:\users\vanshika\anaconda24\lib\site-packages (from torch->easyocr) (2021.4.0)
# Requirement already satisfied: intel-openmp==2021.* in c:\users\vanshika\anaconda24\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch->easyocr) (2021.4.0)
# Requirement already satisfied: tbb==2021.* in c:\users\vanshika\anaconda24\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch->easyocr) (2021.13.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\vanshika\anaconda24\lib\site-packages (from jinja2->torch->easyocr) (2.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\vanshika\anaconda24\lib\site-packages (from requests->torchvision>=0.5->easyocr) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\vanshika\anaconda24\lib\site-packages (from requests->torchvision>=0.5->easyocr) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\vanshika\anaconda24\lib\site-packages (from requests->torchvision>=0.5->easyocr) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\vanshika\anaconda24\lib\site-packages (from requests->torchvision>=0.5->easyocr) (2024.7.4)
# Requirement already satisfied: mpmath>=0.19 in c:\users\vanshika\anaconda24\lib\site-packages (from sympy->torch->easyocr) (1.3.0)
# [([[1, 0], [195, 0], [195, 39], [1, 39]],
#   'TN 48 AD 6592',
#   0.49710993846527285)]
